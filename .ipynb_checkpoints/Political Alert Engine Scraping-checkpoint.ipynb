# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import requests
import pandas as pd
import numpy as np

contracts_url = 'https://www.politicalalertengine.com/api/contracts/all'

r = requests.get(contracts_url)

contracts = r.json()

prices_url = 'https://www.politicalalertengine.com/api/analytics/dataByIds/%d'

prices = requests.get(prices_url % 4390).json()

# %%
get_prices(4390)
# Out:
#                                         id  predictItId  lastTradePrice  \
# date
# 2019-06-08 03:38:31.926000+00:00     80122         4390            56.0
# 2019-06-09 13:37:46.179000+00:00  22715824         4390            55.0
# 2019-06-09 23:35:36.308000+00:00  22740420         4390            56.0
# 2019-06-11 03:30:40.709000+00:00  22810673         4390            55.0
# 2019-06-11 10:09:38.213000+00:00   2592337         4390            56.0
# ...                                    ...          ...             ...
# 2020-12-01 15:37:59.165000+00:00  28124854         4390            87.0
# 2020-12-01 15:39:01.153000+00:00  28124858         4390            88.0
# 2020-12-01 15:46:57.966000+00:00  28124931         4390            89.0
# 2020-12-01 16:05:06.881000+00:00  28125086         4390            88.0
# 2020-12-01 16:27:12.669000+00:00  28125255         4390            89.0
#
#                                  lastClose                          dateCol
# date
# 2019-06-08 03:38:31.926000+00:00      None 2019-06-08 03:38:31.926000+00:00
# 2019-06-09 13:37:46.179000+00:00      None 2019-06-09 13:37:46.179000+00:00
# 2019-06-09 23:35:36.308000+00:00      None 2019-06-09 23:35:36.308000+00:00
# 2019-06-11 03:30:40.709000+00:00      None 2019-06-11 03:30:40.709000+00:00
# 2019-06-11 10:09:38.213000+00:00      None 2019-06-11 10:09:38.213000+00:00
# ...                                    ...                              ...
# 2020-12-01 15:37:59.165000+00:00      None 2020-12-01 15:37:59.165000+00:00
# 2020-12-01 15:39:01.153000+00:00      None 2020-12-01 15:39:01.153000+00:00
# 2020-12-01 15:46:57.966000+00:00      None 2020-12-01 15:46:57.966000+00:00
# 2020-12-01 16:05:06.881000+00:00      None 2020-12-01 16:05:06.881000+00:00
# 2020-12-01 16:27:12.669000+00:00      None 2020-12-01 16:27:12.669000+00:00
#
# [14915 rows x 5 columns]

# %%
def get_prices(c_id):
    df = requests.get(prices_url % c_id).json()
    df = pd.DataFrame(df)
    df['date'] = pd.to_datetime(df['date'])
    df['lastTradePrice'] = df['lastTradePrice'].astype(np.float64)
    df['dateCol'] = df['date']
    df= df.set_index('date')
    return df

# %%
df = pd.DataFrame(prices)

df['date'] = pd.to_datetime(df['date'])
df['lastTradePrice'] = df['lastTradePrice'].astype(np.float64)

c_df = pd.DataFrame(contracts)

c_df[c_df['predictItId'] == 4390]

import matplotlib.pyplot as plt
fig = plt.figure(figsize=(20,10))
plt.plot(df['date'],df['lastTradePrice'])

# %%
df['dateCol'] = df['date']
df= df.set_index('date')


df = df[df.index <= '2020-10-20']

# %%
daily_px = df.resample('1D',how='mean')
daily_px = daily_px.ffill()
daily_px = daily_px.bfill()

daily_px.index += datetime.timedelta(days=1)

plt.plot(daily_px['lastTradePrice'])

plt.show()

daily_px['ret'] = daily_px['lastTradePrice'].diff()

_ = plt.hist(daily_px['ret'],bins=50)
plt.show()

plt.scatter(daily_px['ret'],daily_px['ret'].shift(-1))
plt.show()

daily_px['ret'].corr(daily_px['ret'].shift(-1))
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).mean()
#   """Entry point for launching an IPython kernel.
# 0.07467864919678248

# %%
df['lastTradePrice']
# Out:
# 0        56.0
# 1        55.0
# 2        56.0
# 3        55.0
# 4        56.0
#          ...
# 14888    87.0
# 14889    86.0
# 14890    87.0
# 14891    86.0
# 14892    87.0
# Name: lastTradePrice, Length: 14893, dtype: float64

# %%
c_df['parentId']
# Out:
# 0       5629.0
# 1       5550.0
# 2       5560.0
# 3       5583.0
# 4       5610.0
#          ...
# 8835    6028.0
# 8836    5344.0
# 8837    6040.0
# 8838    6037.0
# 8839    6374.0
# Name: parentId, Length: 8840, dtype: float64

# %%
# 3698 - id for market on various candidates for president
# 1. after jump in longshot price, should mean-revert (e.g andrew yang rallies)

# %%
c_prez = c_df[c_df['parentId'] == 3698]

# %%
prez_dfs = [get_prices(r['predictItId']) for idx,r in c_prez.iterrows()]

# %%
len(prez_dfs)
# Out:
# 26

# %%
fig = plt.figure(figsize=(30,15))
for idx,p_df in enumerate(prez_dfs):
#     p_df = p_df[(p_df.index >= '2020-11-03') & (p_df.index <= '2020-11-05')]
    plt.plot(p_df.index,p_df['lastTradePrice'],label=c_prez.iloc[idx]['name'])
plt.legend()

# %%
# election night

fig = plt.figure(figsize=(30,15))
for idx,p_df in enumerate(prez_dfs):
    p_df = p_df[(p_df.index >= '2020-11-03') & (p_df.index <= '2020-11-05')]
    plt.plot(p_df.index,p_df['lastTradePrice'],label=c_prez.iloc[idx]['name'])
plt.legend()

# %%
c_df[c_df['longName'].str.contains('presidential election') & c_df['longName'].str.contains('2020')][['longName','parentId']]
# Out:
#                                                longName  parentId
# 1747  Will a Republican candidate win OH in the 2020...    5600.0
# 2878  Will a Republican candidate win NH in the 2020...    5598.0
# 3932  Will a Democratic candidate win NH in the 2020...    5598.0
# 5389  Will a Republican candidate win NC in the 2020...    5599.0
# 5501  Will a Democratic candidate win TX in the 2020...    5798.0
# 5894  Will Mark Cuban win the 2020 U.S. presidential...    3698.0
# 6042  Will a Democratic candidate win Minnesota in t...    5597.0
# 6094  Will a Republican candidate win TX in the 2020...    5798.0
# 6365  Will a Republican candidate win NV in the 2020...    5601.0
# 6622  Will Mark Zuckerberg win the 2020 U.S. preside...    3698.0
# 6623  Will Amy Klobuchar win the 2020 U.S. president...    3698.0
# 6624  Will John Kasich win the 2020 U.S. presidentia...    3698.0
# 6625  Will Bernie Sanders win the 2020 U.S. presiden...    3698.0
# 6634  Will Mike Pence win the 2020 U.S. presidential...    3698.0
# 6635  Will Kirsten Gillibrand win the 2020 U.S. pres...    3698.0
# 6647  Will Tulsi Gabbard win the 2020 U.S. president...    3698.0
# 6663  Will Nikki Haley win the 2020 U.S. presidentia...    3698.0
# 6703  Will a Democratic candidate win Pennsylvania i...    5543.0
# 6712  Will a Republican candidate win Pennsylvania i...    5543.0
# 6714  Will a Democratic candidate win Wisconsin in t...    5542.0
# 6715  Will a Republican candidate win Wisconsin in t...    5542.0
# 6721  Will a Democratic candidate win Michigan in th...    5545.0
# 6722  Will a Republican candidate win Arizona  in th...    5596.0
# 6724  Will a Democratic candidate win GA in the 2020...    5604.0
# 6863  Will a Democratic candidate win NV in the 2020...    5601.0
# 6883  Will a Democratic candidate win NC in the 2020...    5599.0
# 6985  Will Donald Trump win the 2020 U.S. presidenti...    3698.0
# 6989  Will Kamala Harris win the 2020 U.S. president...    3698.0
# 6998  Will Elizabeth Warren win the 2020 U.S. presid...    3698.0
# 7000  Will Cory Booker win the 2020 U.S. presidentia...    3698.0
# 7032  Will a Democratic candidate win Arizona in the...    5596.0
# 7105  Will a Republican candidate win VA in the 2020...    5602.0
# 7106  Will a Republican candidate win IA in the 2020...    5603.0
# 7107  Will a Democratic candidate win IA in the 2020...    5603.0
# 7111  Will a Democratic candidate win CO in the 2020...    5605.0
# 7112  Will a Republican candidate win CO in the 2020...    5605.0
# 7113  Will a Democratic candidate win OH in the 2020...    5600.0
# 7337  Will Mike Bloomberg win the 2020 U.S. presiden...    3698.0
# 7339  Will Andrew Yang win the 2020 U.S. presidentia...    3698.0
# 7340  Will Pete Buttigieg win the 2020 U.S. presiden...    3698.0
# 7345  Will Sherrod Brown win the 2020 U.S. president...    3698.0
# 7389  Will Beto O'Rourke win the 2020 U.S. president...    3698.0
# 7392  Will a Democratic candidate win Florida in the...    5544.0
# 7581  Will a Republican candidate win Florida in the...    5544.0
# 7660  Will a Democratic candidate win VA in the 2020...    5602.0
# 7838  Will Joe Biden win the 2020 U.S. presidential ...    3698.0
# 7859  Will a Republican candidate win Michigan in th...    5545.0
# 7972  Will Hillary Clinton win the 2020 U.S. preside...    3698.0
# 7973  2020 presidential election winner? ( Jo Jorgen...    3698.0
# 7974  2020 presidential election winner? ( Kanye Wes...    3698.0
# 7975  2020 presidential election winner? ( Howie Haw...    3698.0
# 8423  Will a Republican candidate win GA in the 2020...    5604.0
# 8472  Will a Republican candidate win Minnesota in t...    5597.0
# 8482  Will Andrew Cuomo win the 2020 U.S. presidenti...    3698.0
# 8599  Will Paul Ryan win the 2020 U.S. presidential ...    3698.0

# %%
#######################
# time of day effects #
#######################

# average/median intraday price movement
plt.locator_params(nbins=10)

g_day = df.groupby(df.index.date)
# g_week = df.groupby(pd.Grouper(key='dateCol',freq='W-MON'))
fig = plt.figure(figsize=(20,10))
price_days = [] 
for n,g in g_day:
    if len(g) < 5:
        continue
#     print(g.columns)
#     g = g.set_index('date')
    g = g.sort_index()
#     print(g)
    g = g.resample('30T', how='mean').interpolate(method='time')
#     print(g)
    midnight = g.index[0].replace(hour=0,minute=0, second=0,microsecond=0)
#     print(pd.date_range(midnight, midnight + datetime.timedelta(hours=23,minutes=59),freq='30T'))
    g = g.reindex(pd.date_range(midnight, midnight + datetime.timedelta(hours=23,minutes=59),freq='30T'))
#     print(g)
#     print(g)
    g = g.bfill()
    g = g.ffill()
    start_price = g['lastTradePrice'].iloc[0]
    
#     xaxis = g.index.time
    xaxis = g.index - g.index[0]
#     print(xaxis)
    
    plt.plot([pd.to_datetime('2020-01-01').normalize() + dt for dt in xaxis],g['lastTradePrice'] - start_price,alpha=0.3)
#     print(len(g['lastTradePrice'].values))
    price_days.append(list(g['lastTradePrice'].values))
plt.ylim((-10,10))
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:19: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).mean()
# (-10, 10)

# %%
price_days = np.array(price_days)

# %%
print('expect %d days of data' % (df.index[-1] - df.index[0]).days)
# Out:
# expect 499 days of data

# %%
print('actually %d days of data' % len(price_days))
# Out:
# actually 431 days of data

# %%
price_diffs
# Out:
# array([[ 0.00000000e+00, -1.03906266e-03, -2.07812532e-03, ...,
#          1.15399213e+00,  1.15295307e+00,  1.15191401e+00],
#        [ 0.00000000e+00, -1.03906266e-03, -1.00207813e+00, ...,
#         -1.34600787e+00, -1.34704693e+00, -1.34808599e+00],
#        [ 0.00000000e+00, -1.03906266e-03, -2.07812532e-03, ...,
#         -1.84600787e+00, -1.84704693e+00, -1.84808599e+00],
#        ...,
#        [ 0.00000000e+00, -1.03906266e-03,  9.97921875e-01, ...,
#          5.82065880e+00,  5.65295307e+00,  5.65191401e+00],
#        [ 0.00000000e+00,  2.48960937e-01,  2.47921875e-01, ...,
#          1.90399213e+00,  9.02953072e-01,  1.90191401e+00],
#        [ 0.00000000e+00,  8.32294271e-01,  1.64588541e-01, ...,
#         -1.34600787e+00, -2.47046928e-01, -3.93540536e-01]])

# %%
price_diffs = pri

# %%
avg_ret = (price_days[:,-1] - price_days[:,0]).mean()

# %%
# price_chngs = np.diff(price_days,axis=1)
dt = datetime.datetime(2020,1,1).replace(hour=0,minute=0, second=0,microsecond=0)
xaxis = pd.date_range(dt, dt + datetime.timedelta(hours=23,minutes=59),freq='30T').time

price_chngs = (price_days[:,1:] - price_days[:,:-1])
price_chngs -= avg_ret / price_chngs.shape[1]

price_diffs = np.concatenate(([[0]]*len(price_chngs),price_chngs.cumsum(axis=1)),axis=1)
#
# price_diffs = (price_days[:,:].T - price_days[:,0]).T
fig = plt.figure(figsize=(10,5))
ax1 = fig.add_subplot(111)

ax2 = ax1.twinx()
ax1.plot(xaxis,price_diffs.mean(axis=0),label='mean')
ax1.plot(xaxis,np.median(price_diffs,axis=0),label='median')
ax2.plot(xaxis,np.std(price_diffs,axis=0),color='green',label='std')


plt.show()




plt.plot(xaxis[1:], price_chngs.mean(axis=0))
plt.plot(xaxis[1:], price_chngs.std(axis=0))

# %%
# why is standard deviation lower on weekends?

# intraday vol probably lowest from 5:30-10 CST/NYC or so becaus all timezones aree quite late

# %%
price_days.shape
# Out:
# (71, 336)

# %%
avg_ret = (price_days[:,-1] - price_days[:,0]).mean()

# %%
# price_chngs = np.diff(price_days,axis=1)

dt = datetime.datetime(2020,1,1).replace(hour=0,minute=0, second=0,microsecond=0)
xaxis = pd.date_range(dt, dt + datetime.timedelta(days=6,hours=23,minutes=59),freq='30T')

price_chngs = (price_days[:,1:] - price_days[:,:-1])
price_chngs -= avg_ret / price_diffs.shape[1]

price_diffs = np.concatenate(([[0]]*len(price_chngs),price_chngs.cumsum(axis=1)),axis=1)
# (price_days[:,:].T - price_days[:,0]).T

fig = plt.figure(figsize=(10,5))
ax1 = fig.add_subplot(111)

ax2 = ax1.twinx()
ax1.plot(xaxis,price_diffs.mean(axis=0),color='blue',label='mean')
ax1.plot(xaxis,np.median(price_diffs,axis=0),color='orange',label='median')
ax2.plot(xaxis,np.std(price_diffs,axis=0),color='green',label='std')

plt.show()




plt.plot(xaxis[1:], price_chngs.mean(axis=0))
plt.plot(xaxis[1:], price_chngs.std(axis=0))

# %%
from scipy.stats import ttest_ind

# %%
friday_start = 144
friday_end = friday_start + 96

friday_chngs = price_chngs[:,friday_start:friday_end].cumsum(axis=1)[:,-1]
print(friday_chngs.mean(), friday_chngs.std())
# Out:
# -0.2190770397488688 0.9512099871449224

# %%
daily_px = df.resample('1D',how='mean')
daily_px = daily_px.ffill()
daily_px = daily_px.bfill()

daily_px.index += datetime.timedelta(days=1)

plt.plot(daily_px['lastTradePrice'])

plt.show()

daily_px['ret'] = daily_px['lastTradePrice'].diff()

_ = plt.hist(daily_px['ret'],bins=50)
plt.show()

plt.scatter(daily_px['ret'],daily_px['ret'].shift(-1))
plt.show()

daily_px['ret'].corr(daily_px['ret'].shift(-1))
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).mean()
#   """Entry point for launching an IPython kernel.

# %%
import statsmodels.api as sm

# %%
price_diffs.cumsum(axis=1)[:,-1].mean()
# Out:
# 72.42427488395793

# %%
import datetime
day = g_day.get_group(datetime.date(2020,1,1))

# %%
daily_index = pd.date_range("00:01", "23:59", freq="30min").time

# day['lastTradePrice'].reindex(pd.interpolate(method='time')

# %%
df['date'].diff().nlargest(25)
# Out:
# 566    1 days 23:29:17.602000
# 1295   1 days 16:00:23.178000
# 1      1 days 09:59:14.253000
# 162    1 days 05:04:23.353000
# 687    1 days 04:46:52.084000
# 164    1 days 04:01:42.704000
# 4071   1 days 03:57:00.997000
# 3      1 days 03:55:04.401000
# 887    1 days 03:19:23.041000
# 432    1 days 03:03:09.184000
# 1436   1 days 01:56:31.773000
# 1570   1 days 01:09:21.673000
# 1397   1 days 01:05:47.213000
# 498    1 days 00:25:44.458000
# 652    0 days 23:49:40.963000
# 4050   0 days 22:45:12.498000
# 474    0 days 22:44:31.883000
# 348    0 days 22:41:49.531000
# 484    0 days 22:37:45.137000
# 253    0 days 22:24:53.918000
# 586    0 days 22:06:26.613000
# 1259   0 days 21:25:39.103000
# 4190   0 days 20:43:23.966000
# 662    0 days 20:37:06.114000
# 1269   0 days 20:33:01.807000
# Name: date, dtype: timedelta64[ns]
